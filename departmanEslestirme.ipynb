# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# c:\Users\btstajyer\AppData\Local\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\btstajyer\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
printer = pd.read_csv("general.csv")
dept = pd.read_csv("department.csv")
printer.drop(columns="Unnamed: 0").head()
# Out:
#         Tarih   Yil  Ay  Gun         ID  genel_renkli  genel_sb  \
# 0  2025-03-01  2025   3    1     dcolor             0         4
# 1  2025-03-01  2025   3    1     hbinay            30         0
# 2  2025-03-01  2025   3    1  herbilgin             1         0
# 3  2025-03-01  2025   3    1    zyuksel             0         0
# 4  2025-03-01  2025   3    1     aayhan             5         7
#
#    dijital_islemler  toplam
# 0                 0       4
# 1                 0      30
# 2                 0       1
# 3                 8       8
# 4                 1      13

# %%
printer.to_excel("printer.xlsx")
dept.to_excel("dept.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 printer.to_excel("printer.xlsx")
#       2 dept.to_excel("dept.xlsx")
#
# File c:\Users\btstajyer\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:2300, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs, autofilter)
#    2286 from pandas.io.formats.excel import ExcelFormatter
#    2288 formatter = ExcelFormatter(
#    2289     df,
#    2290     na_rep=na_rep,
#    (...)
#    2298     autofilter=autofilter,
#    2299 )
# -> 2300 formatter.write(
#    2301     excel_writer,
#    2302     sheet_name=sheet_name,
#    2303     startrow=startrow,
#    2304     startcol=startcol,
#    2305     freeze_panes=freeze_panes,
# ...

# %%
kisiler = list(printer["ID"].unique())
print(kisiler)
# Out:
# ['dcolor', 'hbinay', 'herbilgin', 'zyuksel', 'aayhan', 'udalyan', 'mbayirli', 'egonce', 'mkarsiv', 'fcolak', 'bbugdayci', 'ebadem', 'ierdil', 'fgulsever', 'carican', 'aapak', 'ubasdas', 'gekim', 'dnoic', 'mkorucu', 'bsamuk', 'dustasi', 'abarkod', 'BSOGUT', 'aildeniz', 'mguder', 'itopcu', 'hakand', 'mecigdem', 'dayakta', 'stjegitim', 'hakdemir', 'sapra', 'eozkan', 'ekoksal', 'ersener', 'hbulut', 'bfirat', 'VBAYANER', 'gakca', 'adogan', 'ihasdemir', 'bsakrak', 'akamera', 'vgemici', 'tcapkin', 'ntanriverdi', 'asablon', 'cer', 'mkarabiyik', 'obali', 'fimetin', 'gkenarli', 'ggirgin', 'ekaradavut', 'ngogce', 'saskin', 'gbakanoglu', 'aozbal', 'amasun', 'mertan', 'ebalaban', 'ogungor', 'gayilmaz', 'stjncakirci', 'eulsever', 'tevirgen', 'ayyilmaz', 'oicoz', ' modified by system 2025-04-29 10:29:20 4', 'gsapmaz', 'baozturk', 'esaribuyuk', 'kbtlideri', 'tcakan', 'hkaragoz', 'bunver', 'ESERT', 'gmasistan', 'fbasak', 'mkofis', 'MMUTLU', 'oasistan', 'iunlu', 'eanli', 'SUYILMAZ', 'gcevik', 'okanat'
# ...

# %%
for i in kisiler:
    print(i)
# Out:
# dcolor
# hbinay
# herbilgin
# zyuksel
# aayhan
# udalyan
# mbayirli
# egonce
# mkarsiv
# fcolak
# bbugdayci
# ebadem
# ierdil
# fgulsever
# carican
# aapak
# ubasdas
# gekim
# dnoic
# mkorucu
# bsamuk
# dustasi
# abarkod
# BSOGUT
# aildeniz
# mguder
# itopcu
# hakand
# mecigdem
# dayakta
# stjegitim
# hakdemir
# sapra
# eozkan
# ekoksal
# ersener
# hbulut
# bfirat
# VBAYANER
# gakca
# adogan
# ihasdemir
# bsakrak
# akamera
# vgemici
# tcapkin
# ntanriverdi
# asablon
# cer
# mkarabiyik
# obali
# fimetin
# gkenarli
# ggirgin
# ekaradavut
# ngogce
# saskin
# gbakanoglu
# aozbal
# amasun
# mertan
# ebalaban
# ogungor
# gayilmaz
# stjncakirci
# eulsever
# tevirgen
# ayyilmaz
# oicoz
#  modified by system 2025-04-29 10:29:20 4
# gsapmaz
# baozturk
# esaribuyuk
# kbtlideri
# tcakan
# hkaragoz
# bunver
# ESERT
# gmasistan
# fbasak
# mkofis
# MMUTLU
# oasistan
# iunlu
# eanli
# SUYILMAZ
# gcevik
# okanat
# rkontrol
# acelebi
# nakilli
# kesmeray
# ezyildiz
# nibolkis
# akapucu
# fyakut
# ...
