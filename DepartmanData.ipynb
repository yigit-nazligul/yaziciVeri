# %%
import pandas as pd
ddata = pd.read_csv('department.csv')
ddata.head()
# Out:
#    S.No.               Display Name SAM Account Name Email Address  \
# 0      1     Tuğçe KUBALAS YILDIRIM         tkubalas             -
# 1      2          Sinan YORGANCIGIL     syorgancigil             -
# 2      3               Gülden DOĞAN           gdogan             -
# 3      4                Sibel YUCEL           syucel             -
# 4      5  Tarık Talha BENLI TELEFON         tbenli-m             -
#
#                                Department  \
# 0                       Kurumsal İletişim
# 1            Pazarlama ve Ticari Strateji
# 2   Satış & Pazarlama / Sales & Marketing
# 3  Müşteri Hizmetleri / Customer Services
# 4                                       -
#
#                                        OU Name
# 0                      isten_ayrilanlar/merkez
# 1                      isten_ayrilanlar/merkez
# 2                      isten_ayrilanlar/merkez
# 3                     isten_ayrilanlar/fabrika
# 4  network_access_groups/wifi_connection/users

# %%
 ddata = ddata.rename(columns=yeniSutun)
ddata.head()
# Out:
#    S.No.                       isim         uname email  \
# 0      1     Tuğçe KUBALAS YILDIRIM      tkubalas     -
# 1      2          Sinan YORGANCIGIL  syorgancigil     -
# 2      3               Gülden DOĞAN        gdogan     -
# 3      4                Sibel YUCEL        syucel     -
# 4      5  Tarık Talha BENLI TELEFON      tbenli-m     -
#
#                                department  \
# 0                       Kurumsal İletişim
# 1            Pazarlama ve Ticari Strateji
# 2   Satış & Pazarlama / Sales & Marketing
# 3  Müşteri Hizmetleri / Customer Services
# 4                                       -
#
#                                          oname
# 0                      isten_ayrilanlar/merkez
# 1                      isten_ayrilanlar/merkez
# 2                      isten_ayrilanlar/merkez
# 3                     isten_ayrilanlar/fabrika
# 4  network_access_groups/wifi_connection/users

# %%
ddata["oname"].unique()
# Out:
# <ArrowStringArray>
# [                                                                                          'isten_ayrilanlar/merkez',
#                                                                                           'isten_ayrilanlar/fabrika',
#                                                                        'network_access_groups/wifi_connection/users',
#                                                                                      'servers/fabrika_servers/users',
#                                                                                          'isten_ayrilanlar/danisman',
#                                                                           'devices/fabrika_otomasyon/boyahane/users',
#                                                                                     'isten_ayrilanlar/yurtdisi_ofis',
#                                                                                                     'danisman_users',
# ...

# %%
silinecek_oular = [
    "isten_ayrilanlar/merkez",
    "isten_ayrilanlar/fabrika",
    "isten_ayrilanlar/uretim",
    "isten_ayrilanlar/danisman",
]

ddata.drop(ddata[ddata["oname"].isin(silinecek_oular)].index, inplace=True)

# %%
ddata["department"].unique()
# Out:
# <ArrowStringArray>
# [                                                       '-',
#                                                     'Sales',
#                                       'Bilgi Teknolojileri',
#                                                  'Boyahane',
#                                                     'Ar-Ge',
#                                        'Ar-Ge ve İnovasyon',
#                                                   'Garment',
#                                          'Insan Kaynaklari',
#                                                     'Bakim',
#                                              'Cozgu Dokuma',
#                    'Müşteri Hizmetleri / Customer Services',
#                               'Çözgü ve Dokuma İşletmeleri',
#                                          'İnsan Kaynakları',
#                  'Makine Geliştirme ve Yardımcı İşletmeler',
#                                        'Maliyet Muhasebesi',
# ...
